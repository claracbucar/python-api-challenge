# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
# import hvplot.pandas
import sys
# !{sys.executable} -m pip install hvplot
# !{sys.executable} -m pip install Cartopy
# !{sys.executable} -m pip install GeoViews
# !{sys.executable} -m pip install pyproj

import pandas as pd
import numpy as np
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# Requirement already satisfied: hvplot in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (0.8.2)
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from hvplot) (2.4.3)
# Requirement already satisfied: colorcet>=2 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from hvplot) (3.0.1)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from hvplot) (1.15.4)
# Requirement already satisfied: pandas in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from hvplot) (1.0.5)
# Requirement already satisfied: numpy>=1.15 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from hvplot) (1.18.5)
# Requirement already satisfied: packaging in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from hvplot) (21.3)
# Requirement already satisfied: panel>=0.11.0 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from hvplot) (0.14.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from bokeh>=1.0.0->hvplot) (9.4.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.0.4)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from bokeh>=1.0.0->hvplot) (4.1.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from bokeh>=1.0.0->hvplot) (3.0.3)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from colorcet>=2->hvplot) (0.5.0)
# Requirement already satisfied: param<2.0,>=1.9.3 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from holoviews>=1.11.0->hvplot) (1.12.3)
# Requirement already satisfied: pyviz_comms>=0.7.4 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from holoviews>=1.11.0->hvplot) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from pandas->hvplot) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from pandas->hvplot) (2020.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from packaging->hvplot) (2.4.7)
# Requirement already satisfied: markdown in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from panel>=0.11.0->hvplot) (3.4.1)
# Requirement already satisfied: requests in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from panel>=0.11.0->hvplot) (2.28.1)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from panel>=0.11.0->hvplot) (4.64.1)
# Requirement already satisfied: bleach in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from panel>=0.11.0->hvplot) (4.1.0)
# Requirement already satisfied: setuptools>=42 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from panel>=0.11.0->hvplot) (47.3.1.post20200622)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from python-dateutil>=2.6.1->pandas->hvplot) (1.15.0)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from markdown->panel>=0.11.0->hvplot) (4.11.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from requests->panel>=0.11.0->hvplot) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from requests->panel>=0.11.0->hvplot) (3.4)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from tqdm>=4.48.0->panel>=0.11.0->hvplot) (0.4.4)
# Requirement already satisfied: webencodings in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown->panel>=0.11.0->hvplot) (3.7.0)
# Collecting Cartopy
#   Using cached Cartopy-0.20.3.tar.gz (10.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\clara\anaconda3\envs\pythondata\python.exe' 'C:\Users\clara\anaconda3\envs\pythondata\lib\site-packages\pip\_vendor\pep517\_in_process.py' get_requires_for_build_wheel 'C:\Users\clara\AppData\Local\Temp\tmpd2mrkb5x'
#        cwd: C:\Users\clara\AppData\Local\Temp\pip-install-iu89efvn\Cartopy
#   Complete output (5 lines):
#   C:\Users\clara\AppData\Local\Temp\pip-install-iu89efvn\Cartopy\setup.py:120: UserWarning: Unable to determine GEOS version. Ensure you have 3.7.2 or later installed, or installation may fail.
#     '.'.join(str(v) for v in GEOS_MIN_VERSION), ))
#   C:\Users\clara\AppData\Local\Temp\pip-install-iu89efvn\Cartopy\setup.py:169: UserWarning: Unable to determine Proj version. Ensure you have 8.0.0 or later installed, or installation may fail.
#     '.'.join(str(v) for v in PROJ_MIN_VERSION), ))
#   Proj version 0.0.0 is installed, but cartopy requires at least version 8.0.0.
#   ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\clara\anaconda3\envs\pythondata\python.exe' 'C:\Users\clara\anaconda3\envs\pythondata\lib\site-packages\pip\_vendor\pep517\_in_process.py' get_requires_for_build_wheel 'C:\Users\clara\AppData\Local\Temp\tmpd2mrkb5x' Check the logs for full command output.
# Collecting GeoViews
#   Using cached geoviews-1.9.6-py2.py3-none-any.whl (508 kB)
# Requirement already satisfied: bokeh<2.5,>=2.4.0 in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from GeoViews) (2.4.3)
# Collecting cartopy>=0.18.0
#   Using cached Cartopy-0.20.3.tar.gz (10.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\clara\anaconda3\envs\pythondata\python.exe' 'C:\Users\clara\anaconda3\envs\pythondata\lib\site-packages\pip\_vendor\pep517\_in_process.py' get_requires_for_build_wheel 'C:\Users\clara\AppData\Local\Temp\tmpkgaeo80o'
#        cwd: C:\Users\clara\AppData\Local\Temp\pip-install-trpbds3k\cartopy
#   Complete output (5 lines):
#   C:\Users\clara\AppData\Local\Temp\pip-install-trpbds3k\cartopy\setup.py:120: UserWarning: Unable to determine GEOS version. Ensure you have 3.7.2 or later installed, or installation may fail.
#     '.'.join(str(v) for v in GEOS_MIN_VERSION), ))
#   C:\Users\clara\AppData\Local\Temp\pip-install-trpbds3k\cartopy\setup.py:169: UserWarning: Unable to determine Proj version. Ensure you have 8.0.0 or later installed, or installation may fail.
#     '.'.join(str(v) for v in PROJ_MIN_VERSION), ))
#   Proj version 0.0.0 is installed, but cartopy requires at least version 8.0.0.
#   ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\clara\anaconda3\envs\pythondata\python.exe' 'C:\Users\clara\anaconda3\envs\pythondata\lib\site-packages\pip\_vendor\pep517\_in_process.py' get_requires_for_build_wheel 'C:\Users\clara\AppData\Local\Temp\tmpkgaeo80o' Check the logs for full command output.
# Requirement already satisfied: pyproj in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (3.2.1)
# Requirement already satisfied: certifi in c:\users\clara\anaconda3\envs\pythondata\lib\site-packages (from pyproj) (2022.12.7)

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0        abha  18.2164   42.5053    283.05        50           0
# 1        1  skelleftea  64.7507   20.9528    271.48       100         100
# 2        2   geraldton -28.7667  114.6000    299.38        65           2
# 3        3    thompson  55.7435  -97.8558    247.24        84           0
# 4        4    portland  45.5234 -122.6762    282.07        86         100
#
#    Wind Speed Country        Date
# 0        0.00      SA  1676772013
# 1        2.57      SE  1676772052
# 2        7.72      AU  1676771882
# 3        1.03      CA  1676771890
# 4        3.60      US  1676771829

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
#issue with geo=True
# cityplot = city_data_df.hvplot.points(x='Lng', y='Lat', geo=True, color='green', size="Humidity",alpha=0.35)
cityplot = city_data_df.hvplot.points(x='Lng', y='Lat', color='green', size="Humidity",alpha=0.35)

# Display the map
cityplot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11108\3556589641.py in <module>
#       2 #issue with geo=True
#       3 # cityplot = city_data_df.hvplot.points(x='Lng', y='Lat', geo=True, color='green', size="Humidity",alpha=0.35)
# ----> 4 cityplot = city_data_df.hvplot.points(x='Lng', y='Lat', color='green', size="Humidity",alpha=0.35)
#       5
#       6 # Display the map
#
# ~\anaconda3\envs\pythondata\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'hvplot'

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_data_df = city_data_df.loc[(city_data_df['Humidity'] < 80)]

# Drop any rows with null values
city_data_df.dropna()

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0            abha  18.2164   42.5053    283.05        50           0
# 2        2       geraldton -28.7667  114.6000    299.38        65           2
# 5        5     yellowknife  62.4560 -114.3525    244.44        76          20
# 6        6          hobart -42.8794  147.3294    301.07        37           0
# 7        7  severo-kurilsk  50.6789  156.1250    267.29        75          99
#
#    Wind Speed Country        Date
# 0        0.00      SA  1676772013
# 2        7.72      AU  1676771882
# 5        1.54      CA  1676772008
# 6        8.75      AU  1676772055
# 7        2.90      RU  1676772056

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[["City", "Lat", "Lng", "Country", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel name"] = np.nan

# Display sample data
hotel_df.head()
# Out:
#          City      Lat       Lng Country  Humidity  Hotel name
# 0        abha  18.2164   42.5053      SA        50         NaN
# 1  skelleftea  64.7507   20.9528      SE       100         NaN
# 2   geraldton -28.7667  114.6000      AU        65         NaN
# 3    thompson  55.7435  -97.8558      CA        84         NaN
# 4    portland  45.5234 -122.6762      US        86         NaN

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories": "accommodation.hotel",
          "apiKey": geoapify_key}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lon = row['Lng']
    print(lat)
    print(lon)

    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle: {lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    print(params)
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# -23.1203
# -134.9692
# {'categories': 'accommodation.hotel', 'apiKey': '534079832250425096b23c7ab671be16', 'filter': 'circle: -134.9692,-23.1203,10000', 'bias': 'proximity:-134.9692,-23.1203'}
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25512\3722934632.py in <module>
#      26
#      27     # Make and API request using the params dictionaty
# ---> 28     name_address = requests.get(f"base_url + params")
#      29
#      30     # Convert the API response to JSON format
#
# ~\anaconda3\envs\pythondata\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~\anaconda3\envs\pythondata\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~\anaconda3\envs\pythondata\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     571             hooks=hooks,
#     572         )
# --> 573         prep = self.prepare_request(req)
#     574
#     575         proxies = proxies or {}
#
# ~\anaconda3\envs\pythondata\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     494             auth=merge_setting(auth, self.auth),
#     495             cookies=merged_cookies,
# --> 496             hooks=merge_hooks(request.hooks, self.hooks),
#     497         )
#     498         return p
#
# ~\anaconda3\envs\pythondata\lib\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     366
#     367         self.prepare_method(method)
# --> 368         self.prepare_url(url, params)
#     369         self.prepare_headers(headers)
#     370         self.prepare_cookies(cookies)
#
# ~\anaconda3\envs\pythondata\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     438         if not scheme:
#     439             raise MissingSchema(
# --> 440                 f"Invalid URL {url!r}: No scheme supplied. "
#     441                 f"Perhaps you meant http://{url}?"
#     442             )
#
# MissingSchema: Invalid URL 'base_url + params': No scheme supplied. Perhaps you meant http://base_url + params?

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
